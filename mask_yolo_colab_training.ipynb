# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/mask_project/Yolos' 
#查看當前路徑下之檔案
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b9885df3af7f> in <module>()
# ----> 1 get_ipython().system("ls '/content/gdrive/My Drive/mask_project/Yolos' ")
#       2 #查看當前路徑下之檔案
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     445   # stack.
#     446   result = _run_command(
# --> 447       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     448   shell.user_ns['_exit_code'] = result.returncode
# ...

# %%
# %cd '/content/gdrive/My Drive/mask_project'
# Out:
# /content/gdrive/My Drive/mask_project

# %%
# !git clone 'https://github.com/Alexeyab/darknet.git' '/content/gdrive/My Drive/mask_project/darknet'
# Out:
# Cloning into '/content/gdrive/My Drive/mask_project/darknet'...
# remote: Enumerating objects: 15283, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 15283 (delta 39), reused 51 (delta 26), pack-reused 15186
# Receiving objects: 100% (15283/15283), 13.78 MiB | 7.24 MiB/s, done.
# Resolving deltas: 100% (10350/10350), done.
# Checking out files: 100% (2044/2044), done.

# %%
# %cd '/content/gdrive/My Drive/mask_project/darknet'
#build darknet
# !make
# Out:
# /content/gdrive/My Drive/mask_project/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd '/content/gdrive/My Drive/mask_project/darknet'
# !chmod +x ./darknet
#複製上次未執行完檔案
# Out:
# /content/gdrive/My Drive/mask_project/darknet

# %%
# %cd '/content/gdrive/My Drive/mask_project'
#!python Yolos/creating-files-data-and-name.py
#!python Yolos/pythcreating-train-and-test-txt-files.py
# Out:
# /content/gdrive/My Drive/mask_project

# %%
# Out:
# 測試資料數目：1321
# 訓練資料數目：7486

# %%
import glob
mask=0
nonmask=0
count=0
for filepath in glob.iglob('/content/gdrive/My Drive/mask_project/Yolos/*.txt'):
    count+=1
    f=open(filepath)
    for line in f:
        if line[0]=='0':
            mask+=1
        elif line[0]=='1':
            nonmask+=1
    if count>=100:
      count=0
      print("有口罩樣本{} \n無口罩樣本 {}".format(mask,nonmask))
print("有口罩樣本{} \n無口罩樣本 {}".format(mask,nonmask))
# Out:
# 有口罩樣本105
# 無口罩樣本 51
# 有口罩樣本184
# 無口罩樣本 98
# 有口罩樣本290
# 無口罩樣本 133
# 有口罩樣本384
# 無口罩樣本 180
# 有口罩樣本480
# 無口罩樣本 234
# 有口罩樣本569
# 無口罩樣本 283
# 有口罩樣本677
# 無口罩樣本 324
# 有口罩樣本766
# 無口罩樣本 357
# 有口罩樣本857
# 無口罩樣本 403
# 有口罩樣本953
# 無口罩樣本 444
# 有口罩樣本1061
# 無口罩樣本 460
# 有口罩樣本1158
# 無口罩樣本 510
# 有口罩樣本1255
# 無口罩樣本 542
# 有口罩樣本1354
# 無口罩樣本 597
# 有口罩樣本1474
# 無口罩樣本 651
# 有口罩樣本1484
# 無口罩樣本 811
# 有口罩樣本1489
# 無口罩樣本 980
# 有口罩樣本1504
# 無口罩樣本 1205
# 有口罩樣本1566
# 無口罩樣本 1277
# 有口罩樣本1676
# 無口罩樣本 1311
# 有口罩樣本1688
# 無口罩樣本 1617
# 有口罩樣本1694
# 無口罩樣本 1877
# 有口罩樣本1701
# 無口罩樣本 2126
# 有口罩樣本1709
# 無口罩樣本 2300
# 有口罩樣本1719
# 無口罩樣本 2496
# 有口罩樣本1725
# 無口罩樣本 2614
# 有口罩樣本1735
# 無口罩樣本 2742
# 有口罩樣本1741
# 無口罩樣本 2909
# 有口罩樣本1754
# 無口罩樣本 3096
# 有口罩樣本1763
# 無口罩樣本 3343
# 有口罩樣本1879
# 無口罩樣本 3427
# 有口罩樣本1908
# 無口罩樣本 3587
# 有口罩樣本1922
# 無口罩樣本 3736
# 有口罩樣本1929
# 無口罩樣本 3912
# 有口罩樣本1935
# 無口罩樣本 4113
# 有口罩樣本2186
# 無口罩樣本 4197
# 有口罩樣本2337
# 無口罩樣本 4263
# 有口罩樣本2581
# 無口罩樣本 4337
# 有口罩樣本2775
# 無口罩樣本 4425
# 有口罩樣本2971
# 無口罩樣本 4502
# 有口罩樣本3162
# 無口罩樣本 4602
# ...

# %%
#!chmod +x ./darknet/darknet
# Out:
# chmod: cannot access './darknet/darknet': Not a directory

# %%
! /opt/bin/nvidia-smi
# Out:
# Sun Aug 29 13:28:55 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
% %cd '/content/gdrive/My Drive/mask_project'
# !./darknet/darknet detector train ./Yolos/labelled_data.data ./Yolos/yolov3-tiny.cfg ./Yolos/darknet53.conv.74 -dont_show 第一次訓練

#!./darknet/darknet detector train ./Yolos/labelled_data.data ./Yolos/yolov3-tiny.cfg ./backup/yolov3-tiny_last.weights -dont_show
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/My Drive/mask_project'
# /content
# /bin/bash: ./darknet/darknet: No such file or directory

# %%
% %cd '/content/gdrive/My Drive/mask_project'

# !./darknet/darknet detector train ./Yolos/labelled_data.data ./Yolos/yolov3-tiny.cfg ./Yolos/darknet53.conv.74 -dont_show 2>&1|tee trainRecord.log
#!./darknet/darknet detector train ./Yolos/labelled_data.data ./Yolos/yolov3-tiny.cfg ./backup/yolov3-tiny_last.weights -dont_show 2>&1|tee new_trainRecord.log
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.759403), count: 2, class_loss = 0.113535, iou_loss = 0.132953, total_loss = 0.246488
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.816574), count: 1, class_loss = 0.469283, iou_loss = 0.039969, total_loss = 0.509252
#  total_bbox = 264386, rewritten_bbox = 0.221267 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.811190), count: 4, class_loss = 0.364049, iou_loss = 0.195886, total_loss = 0.559935
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000075, iou_loss = 0.000000, total_loss = 0.000075
#  total_bbox = 264390, rewritten_bbox = 0.221264 %
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 21.23 MB
#  CUDA allocate done!
# Loaded: 0.000069 seconds
#
# ...

# %%
# %cd '/content/gdrive/My Drive/mask_project'
#測試相片
# !./darknet/darknet detect ./Yolos/yolov3-tiny.cfg ./backup/yolov3-tiny_last.weights ./data/mask4.jpg  -dont_show
#可自行輸入測試路徑
#!./darknet/darknet detector test ./cfg/coco.data ./Yolos/yolov3-tiny.cfg ./backup/yolov3-tiny_last.weights
# Out:
# /content/gdrive/My Drive/mask_project
#  CUDA-version: 11010 (11020), GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
# ...

# %%
# %cd '/content/gdrive/My Drive/mask_project'
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
# Out:
# /content/gdrive/My Drive/mask_project

# %%
imShow('predictions.jpg')

# %%
#影片物件偵測
# !./darknet/darknet detector demo ./cfg/coco.data ./Yolos/yolov3-tiny.cfg ./backup/yolov3-tiny_last.weights -dont_show ./data/test1.mp4 -i 0 -out_filename ./data/result.avi
# Out:
#  CUDA-version: 11010 (11020), GPU count: 1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %%
# %cd '/content/gdrive/My Drive/mask_project'
# !python extract_log.py
# Out:
# /content/gdrive/My Drive/mask_project

# %%
#!python extract_log.py
#!python train_loss_visualization.py
# !python train_iou_visualization.py
# Out:
# Traceback (most recent call last):
#   File "pandas/_libs/lib.pyx", line 2004, in pandas._libs.lib.maybe_convert_numeric
# ValueError: Unable to parse string "(iou"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train_iou_visualization.py", line 27, in <module>
#     result[name] = pd.to_numeric(result[name])
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py", line 153, in to_numeric
#     values, set(), coerce_numeric=coerce_numeric
#   File "pandas/_libs/lib.pyx", line 2041, in pandas._libs.lib.maybe_convert_numeric
# ValueError: Unable to parse string "(iou" at position 0

# %%
#視覺話loss
#!/usr/bin/python
#coding=utf-8
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
 
#根據自己的log_loss.txt中的行數修改lines, 修改訓練時的迭代起始次數(start_ite)和结束次数(end_ite)。
lines = 400000
start_ite = 100 #log_loss.txt裡面的最小迭代次數
end_ite = 520516 #log_loss.txt裡面的最大迭代次數
step = 50 #跳行數，決定畫圖的稠密程度
igore = 0 #當開始的loss較大時，你需要忽略前igore次迭代，注意這裡是迭代次數
 
 
y_ticks = [3, 200, 400, 600, 800, 1000]#縱坐標的值，可以自己設置。
data_path =  'train_log_loss.txt' #log_loss的路徑。
 
####-----------------只需要改上面的，下面的可以不改動
names = ['loss', 'avg', 'rate', 'seconds', 'images']
result = pd.read_csv(data_path, skiprows=[x for x in range(lines) if (x<lines*1.0/((end_ite - start_ite)*1.0)*igore or x%step!=9)], error_bad_lines=\
False, names=names)
result.head()
for name in names:
    result[name] = result[name].str.split(' ').str.get(1)
 
result.head()
result.tail()
 
for name in names:
    result[name] = pd.to_numeric(result[name])
result.dtypes
print(result['loss'].values)
 
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
 
 
###-----------設置橫坐標的值。
x_num = len(result['loss'].values)
tmp = (end_ite-start_ite - igore)/(x_num*1.0)
x = []
for i in range(x_num):
    x.append(i*tmp + start_ite + igore)
#print(x)
print('total = %d\n' %x_num)
print('start = %d, end = %d\n' %(x[0], x[-1]))
###----------
 

ax.plot(x, result['loss'].values, color=(255/255,100/255,100/255), label='avg_loss')
#ax.plot(result['loss'].values, label='loss')
#plt.yticks(y_ticks)#如果不想自己設置縱坐標，可以注釋掉。
plt.grid()#顯示網格
ax.legend(loc = 'best')
ax.set_title('The loss curves')
ax.set_xlabel('batches')
fig.savefig('loss')
# Out:
# [676.420166 547.53479  257.375488 309.840729 261.520355 259.870026
#  108.206078  29.242027  20.209612   4.713931   3.073551   2.206138
#    2.201023   2.279579   2.023594   2.228262   2.105746   2.2691
#    2.376713   2.191899   2.333682   2.206239   1.960681   2.177673
#    2.315086   2.055076   1.953675   2.153596   1.758012   2.393095
#    2.156707   2.043228   1.951978   2.235307   1.925518   1.871784
#    2.09883    1.85631    1.867231   2.242768   1.676695   1.617149
#    1.743036   1.538188   1.712451   1.815337   1.553802   1.686285
#    1.645547   1.549161   1.596876   1.491254   1.580284   1.486478
#    1.342147   1.251191   1.500712   1.219843   1.29001    1.420983
#    1.257811   1.354223   1.265316   1.241626   1.284263   1.385723
#    1.216392   1.542006   1.255718   1.171172   1.227957   1.143801
#    1.275123   1.277893   1.262861   1.165292   1.047691   1.353646
#    1.52899    1.124931   1.161037   1.207149   1.063851   1.878557
# ...

# %%
#!/usr/bin/python
#coding=utf-8
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
#根據log_iou修改行數
lines = 5374
step = 5000
start_ite = 100
end_ite = 10000
igore = 100
data_path =  'train_log_iou.txt' #log_loss的路徑。
 
names = ['Region Avg IOU', 'Class', 'Obj', 'No Obj', '.5_Recall', '.7_Recall', 'count']
#result = pd.read_csv('log_iou.txt', skiprows=[x for x in range(lines) if (x%10==0 or x%10==9)]\
result = pd.read_csv(data_path, skiprows=[x for x in range(lines) if (x<lines*1.0/((end_ite - start_ite)*1.0)*igore or x%step!=0)]\
, error_bad_lines=False, names=names)
result.head()
result['Obj']=result['Obj'].str.split('IOU:').str.get(1)

'''
for name in names:
  result[name] = result[name].str.split(': ').str.get(1)
'''
result.head()
result.tail()
#result['Obj'] = result['Obj'].astype(str)
number=[]
for line in range(len(result['Obj'])):
  number.append(0)
  number[line]=result['Obj'][line].split(')')[0]
number = list(map(float, number))
print(number)

  #number=[int(temp)for temp in line.split() if temp.isdigit()]


#number=[int(temp)for temp in result['Obj'].str.split() if temp.isdigit()]

'''
for name in names:
    result[name] = pd.to_numeric(result[name])
'''
result.dtypes
 
 
####--------------
x_num = len(number)
tmp = (end_ite-start_ite - igore)/(x_num*1.0)
x = []
for i in range(x_num):
	x.append(i*tmp + start_ite + igore)
print(x)
print('total = %d\n' %x_num)
print('start = %d, end = %d\n' %(x[0], x[-1]))
####-------------
 
 
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x, number, label='Region Avg IOU')
#ax.plot(result['Avg Recall'].values, label='Avg Recall')
plt.grid()
ax.legend(loc='best')
ax.set_title('The Region Avg IOU curves')
ax.set_xlabel('batches')
fig.savefig('iou')
# Out:
# [0.530173, 0.552779, 0.481612, 0.634358, 0.476715, 0.0, 0.606328, 0.666446, 0.0, 0.493203, 0.36509, 0.595907, 0.466857, 0.635054, 0.381737, 0.556631, 0.590666, 0.432301, 0.694731, 0.53816, 0.305667, 0.508495, 0.36433, 0.593453, 0.250129, 0.600546, 0.61728, 0.605541, 0.563656, 0.419491, 0.493305, 0.735056, 0.364769, 0.613412, 0.506317, 0.581104, 0.0, 0.0, 0.466299, 0.53088, 0.0, 0.447021, 0.677134, 0.744844, 0.615639, 0.627115, 0.0, 0.649292, 0.0, 0.499397, 0.47873, 0.515702, 0.0, 0.501123, 0.587589, 0.53838, 0.533449, 0.484522, 0.52027, 0.515972, 0.229349, 0.608277, 0.516302, 0.633789, 0.602125, 0.48868, 0.499755, 0.58238, 0.0, 0.502942, 0.191881, 0.580697, 0.0, 0.606638, 0.529521, 0.68881, 0.486505, 0.609638, 0.672278, 0.479752, 0.519201, 0.54169, 0.522338, 0.598604, 0.426522, 0.413049, 0.455539, 0.688348, 0.805608, 0.552997, 0.490955, 0.526243, 0.500727, 0.501428, 0.406175, 0.592896, 0.0, 0.628664, 0.497757, 0.469666, 0.565325, 0.56121, 0.0, 0.499129, 0.365802, 0.639256, 0.441402, 
# ...
